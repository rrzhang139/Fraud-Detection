# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv("train_eda")
test = pd.read_csv("test_eda")

# %% [markdown]
# ## Missing Values

# %%
# Remove values that have 95% missing value or higher

for feature in dataset.columns:
    if np.round(dataset[feature].isnull().mean(), 4) > .9:
        del dataset[feature]

for feature in test.columns:
    if np.round(test[feature].isnull().mean(), 4) > .9:
        del test[feature]

# %%
dataset.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD     card1  \
# 0        3567540        0      16.554679        3.663562         W  7.497762
# 1        3567541        0      16.554681        3.432373         W  9.439625
# 2        3567542        0      16.554683        4.799914         W  9.714745
# 3        3567543        0      16.554686        5.141664         W  8.969669
# 4        3567544        0      16.554687        4.681668         W  9.028219
#
#       card2     card3       card4     card5  ... id_29  id_31  id_35  id_36  \
# 0  5.081404  5.010635  mastercard  4.762174  ...   NaN    NaN    NaN    NaN
# 1  5.590987  5.010635        visa  5.111988  ...   NaN    NaN    NaN    NaN
# 2  6.165418  5.010635        visa  4.836282  ...   NaN    NaN    NaN    NaN
# 3  6.202536  5.010635        visa  5.420535  ...   NaN    NaN    NaN    NaN
# 4  6.276643  5.010635  mastercard  5.411646  ...   NaN    NaN    NaN    NaN
#
#   id_37 id_38  DeviceType  DeviceInfo  day  hour
# 0   NaN   NaN         NaN         NaN    3     2
# 1   NaN   NaN         NaN         NaN    3     2
# 2   NaN   NaN         NaN         NaN    3     2
# 3   NaN   NaN         NaN         NaN    3     2
# 4   NaN   NaN         NaN         NaN    3     2
#
# [5 rows x 366 columns]

# %%
# Numerical
numerical_features_train = [feature for feature in dataset.columns if dataset[feature].dtype != 'O']
numerical_features_test = [feature for feature in test.columns if test[feature].dtype != 'O']
print(len(numerical_features_train))
print(len(numerical_features_test))
print([feature for feature in numerical_features_train if feature not in numerical_features_test])
# #Discrete: Take the mode
# discrete_features_train = [feature for feature in numerical_features_train if (len(dataset[feature].unique()) < 20) & (feature != "isFraud") ]
# discrete_features_test = [feature for feature in numerical_features_test if (len(test[feature].unique()) < 20) & (feature != "isFraud") ]
# # Continuous: Take mean
# continuous_features_train = [feature for feature in numerical_features_train if (feature not in discrete_features_train) & (feature != 'TransactionID')]
# continuous_features_test = [feature for feature in numerical_features_test if (feature not in discrete_features_test) & (feature != 'TransactionID')]

#Cat: Mode
categorical_features_train = [feature for feature in dataset.columns if dataset[feature].dtype == 'O']
categorical_features_test = [feature for feature in test.columns if test[feature].dtype == 'O']
# Out:
# 340
# 396
# ['isFraud', 'id_01', 'id_02', 'id_05', 'id_06', 'id_09', 'id_10', 'id_11', 'id_13', 'id_17', 'id_19', 'id_20']

# %%
for i in numerical_features_train:
    #Do the mean
    dataset[i].fillna(dataset[i].mean(),inplace=True)
for i in numerical_features_test:
    #Do the mean
    test[i].fillna(test[i].mean(),inplace=True)
    
for i in categorical_features_train:
    if len(dataset[i].value_counts()) < 3: # If its a boolean
        dataset[i].fillna('Unknown',inplace=True)
    else:
        dataset[i].fillna(dataset[i].mode()[0],inplace=True)
for i in categorical_features_test:
    if len(test[i].value_counts()) < 3: # If its a boolean
        test[i].fillna('Unknown',inplace=True)
    else:
        test[i].fillna(test[i].mode()[0],inplace=True)
    
dataset[numerical_features_train].isnull().sum()
# Out:
# TransactionID     0
# isFraud           0
# TransactionDT     0
# TransactionAmt    0
# card1             0
#                  ..
# id_17             0
# id_19             0
# id_20             0
# day               0
# hour              0
# Length: 340, dtype: int64

# %%
dataset.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD     card1  \
# 0        3567540        0      16.554679        3.663562         W  7.497762
# 1        3567541        0      16.554681        3.432373         W  9.439625
# 2        3567542        0      16.554683        4.799914         W  9.714745
# 3        3567543        0      16.554686        5.141664         W  8.969669
# 4        3567544        0      16.554687        4.681668         W  9.028219
#
#       card2     card3       card4     card5  ...    id_29        id_31  \
# 0  5.081404  5.010635  mastercard  4.762174  ...  Unknown  chrome 66.0
# 1  5.590987  5.010635        visa  5.111988  ...  Unknown  chrome 66.0
# 2  6.165418  5.010635        visa  4.836282  ...  Unknown  chrome 66.0
# 3  6.202536  5.010635        visa  5.420535  ...  Unknown  chrome 66.0
# 4  6.276643  5.010635  mastercard  5.411646  ...  Unknown  chrome 66.0
#
#      id_35    id_36    id_37    id_38  DeviceType  DeviceInfo  day  hour
# 0  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 1  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 2  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 3  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 4  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
#
# [5 rows x 366 columns]

# %%
# Wee have replaced all Null categorical variables with "Unknown"
# dataset['id_33'].value_counts()

# %% [markdown]
# ## Label Encoder

# %%
# Transform all X_lables into integers for xgb model
# from sklearn import preprocessing

# le = preprocessing.LabelEncoder()
# for feature in categorical_features_train:
#     dataset[feature]=dataset[feature].astype(str)
#     le.fit(dataset[feature])
#     dataset[feature] = le.transform(dataset[feature])

# for feature in categorical_features_test:
#     test[feature]=test[feature].astype(str)
#     le.fit(test[feature])
#     test[feature] = le.transform(test[feature])

# %%
# Transformed them into integers, we will rank them later
# dataset['P_emaildomain'][0].dtype

# %%
dataset.head()
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD     card1  \
# 0        3567540        0      16.554679        3.663562         W  7.497762
# 1        3567541        0      16.554681        3.432373         W  9.439625
# 2        3567542        0      16.554683        4.799914         W  9.714745
# 3        3567543        0      16.554686        5.141664         W  8.969669
# 4        3567544        0      16.554687        4.681668         W  9.028219
#
#       card2     card3       card4     card5  ...    id_29        id_31  \
# 0  5.081404  5.010635  mastercard  4.762174  ...  Unknown  chrome 66.0
# 1  5.590987  5.010635        visa  5.111988  ...  Unknown  chrome 66.0
# 2  6.165418  5.010635        visa  4.836282  ...  Unknown  chrome 66.0
# 3  6.202536  5.010635        visa  5.420535  ...  Unknown  chrome 66.0
# 4  6.276643  5.010635  mastercard  5.411646  ...  Unknown  chrome 66.0
#
#      id_35    id_36    id_37    id_38  DeviceType  DeviceInfo  day  hour
# 0  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 1  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 2  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 3  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
# 4  Unknown  Unknown  Unknown  Unknown     Unknown     Windows    3     2
#
# [5 rows x 366 columns]

# %%
# ## 
# print(len(categorical_features_train))
# print(len(categorical_features_test))

for feature in categorical_features_train:
    train_ = pd.DataFrame(dataset.groupby('isFraud')[feature].value_counts(normalize=True).rename('percentage')
                         .mul(100)
                         .reset_index()
                         .sort_values(feature))
    train_ = train_.set_index(train_[feature])
    print(train_)
    dict_= {}
    for label in train_[feature].unique(): # go thru eveery unique label and find diffreence % btwn isFraud
        #Within each category, find diff
        #Create dictionary where feature label is key and percentage diff is val
        dict_[label] = train_.loc[(train_['isFraud'] == 1) & (train_[feature] == label)]['percentage'] - train_.loc[(train_['isFraud'] == 0) & (train_[feature] == label)]['percentage']
    
    #After going through each label, order by largest diff: If most +, then it will be numbered last, if most - then numbered first
    #EX: 0 index = more legit than fraud, n index = more fraud than legit
    labels_ordered = sorted(dict_.items(), reverse=True)
    labels_ordered={k[0]:i for i,k in enumerate(labels_ordered,0)}
    print(labels_ordered)
    # Map by replacing the dic key with the value in each feature column
    dataset[feature]=dataset[feature].map(labels_ordered)
    if(feature in test.columns):
        test[feature] = test[feature].map(labels_ordered)
# Out:
#            isFraud ProductCD  percentage
# ProductCD
# C                0         C    7.384647
# C                1         C   34.085213
# H                0         H    2.770545
# H                1         H    4.761905
# R                0         R    4.332882
# R                1         R    7.769424
# S                0         S    2.093532
# S                1         S    9.022556
# W                0         W   83.418394
# W                1         W   44.360902
# {'W': 0, 'S': 1, 'R': 2, 'H': 3, 'C': 4}
#                   isFraud             card4  percentage
# card4
# american express        0  american express    0.916571
# american express        1  american express    0.751880
# discover                0          discover    1.187376
# discover                1          discover    2.255639
# mastercard              0        mastercard   30.173940
# mastercard              1        mastercard   28.070175
# visa                    0              visa   67.722112
# visa                    1              visa   68.922306
# {'visa': 0, 'mastercard': 1, 'discover': 2, 'american express': 3}
#         isFraud   card6  percentage
# card6
# credit        0  credit   23.226747
# credit        1  credit   47.117794
# debit         0   debit   76.773253
# debit         1   debit   52.882206
# {'debit': 0, 'credit': 1}
#                isFraud  P_emaildomain  percentage
# P_emaildomain
# aim.com              0        aim.com    0.052078
# anonymous.com        0  anonymous.com    6.790959
# anonymous.com        1  anonymous.com    9.523810
# aol.com              0        aol.com    5.332778
# aol.com              1        aol.com    4.511278
# ...                ...            ...         ...
# yahoo.com            1      yahoo.com   12.280702
# yahoo.com.mx         0   yahoo.com.mx    0.177065
# yahoo.es             0       yahoo.es    0.031247
# yahoo.fr             0       yahoo.fr    0.135403
# ymail.com            0      ymail.com    0.354130
#
# [70 rows x 3 columns]
# {'ymail.com': 0, 'yahoo.fr': 1, 'yahoo.es': 2, 'yahoo.com.mx': 3, 'yahoo.com': 4, 'yahoo.co.uk': 5, 'windstream.net': 6, 'web.de': 7, 'verizon.net': 8, 'twc.com': 9, 'suddenlink.net': 10, 'sc.rr.com': 11, 'sbcglobal.net': 12, 'rocketmail.com': 13, 'roadrunner.com': 14, 'q.com': 15, 'ptd.net': 16, 'protonmail.com': 17, 'prodigy.net.mx': 18, 'outlook.es': 19, 'outlook.com': 20, 'optonline.net': 21, 'netzero.net': 22, 'netzero.com': 23, 'msn.com': 24, 'me.com': 25, 'mail.com': 26, 'mac.com': 27, 'live.com.mx': 28, 'live.com': 29, 'juno.com': 30, 'icloud.com': 31, 'hotmail.fr': 32, 'hotmail.es': 33, 'hotmail.com': 34, 'hotmail.co.uk': 35, 'gmail.com': 36, 'gmail': 37, 'frontiernet.net': 38, 'frontier.com': 39, 'embarqmail.com': 40, 'earthlink.net': 41, 'cox.net': 42, 'comcast.net': 43, 'charter.net': 44, 'cfl.rr.com': 45, 'centurylink.net': 46, 'cableone.net': 47, 'bellsouth.net': 48, 'att.net': 49, 'aol.com': 50, 'anonymous.com': 51, 'aim.com': 52}
#                 isFraud   R_emaildomain  percentage
# R_emaildomain
# aim.com               0         aim.com    0.010416
# anonymous.com         0   anonymous.com    2.822623
# anonymous.com         1   anonymous.com    5.764411
# aol.com               0         aol.com    0.374961
# att.net               0         att.net    0.020831
# bellsouth.net         0   bellsouth.net    0.010416
# comcast.net           0     comcast.net    0.083325
# cox.net               0         cox.net    0.020831
# earthlink.net         0   earthlink.net    0.010416
# embarqmail.com        0  embarqmail.com    0.010416
# gmail                 0           gmail    0.010416
# gmail.com             0       gmail.com   90.605145
# gmail.com             1       gmail.com   75.187970
# hotmail.co.uk         0   hotmail.co.uk    0.010416
# hotmail.com           0     hotmail.com    3.114259
# hotmail.com           1     hotmail.com    9.273183
# hotmail.es            0      hotmail.es    0.020831
# hotmail.fr            0      hotmail.fr    0.072909
# icloud.com            0      icloud.com    0.239558
# icloud.com            1      icloud.com    1.002506
# juno.com              0        juno.com    0.010416
# live.com              1        live.com    0.250627
# live.com              0        live.com    0.052078
# live.com.mx           1     live.com.mx    3.007519
# live.com.mx           0     live.com.mx    0.072909
# mac.com               0         mac.com    0.010416
# mail.com              0        mail.com    0.010416
# me.com                0          me.com    0.062493
# msn.com               0         msn.com    0.041662
# optonline.net         0   optonline.net    0.010416
# outlook.com           1     outlook.com    2.005013
# outlook.com           0     outlook.com    0.229143
# outlook.es            0      outlook.es    0.010416
# prodigy.net.mx        0  prodigy.net.mx    0.010416
# roadrunner.com        0  roadrunner.com    0.010416
# sbcglobal.net         0   sbcglobal.net    0.135403
# scranton.edu          0    scranton.edu    0.031247
# twc.com               0         twc.com    0.010416
# verizon.net           0     verizon.net    0.062493
# web.de                0          web.de    0.041662
# yahoo.co.uk           0     yahoo.co.uk    0.010416
# yahoo.com             0       yahoo.com    1.395688
# yahoo.com             1       yahoo.com    3.508772
# yahoo.com.mx          0    yahoo.com.mx    0.177065
# yahoo.fr              0        yahoo.fr    0.135403
# ymail.com             0       ymail.com    0.031247
# {'ymail.com': 0, 'yahoo.fr': 1, 'yahoo.com.mx': 2, 'yahoo.com': 3, 'yahoo.co.uk': 4, 'web.de': 5, 'verizon.net': 6, 'twc.com': 7, 'scranton.edu': 8, 'sbcglobal.net': 9, 'roadrunner.com': 10, 'prodigy.net.mx': 11, 'outlook.es': 12, 'outlook.com': 13, 'optonline.net': 14, 'msn.com': 15, 'me.com': 16, 'mail.com': 17, 'mac.com': 18, 'live.com.mx': 19, 'live.com': 20, 'juno.com': 21, 'icloud.com': 22, 'hotmail.fr': 23, 'hotmail.es': 24, 'hotmail.com': 25, 'hotmail.co.uk': 26, 'gmail.com': 27, 'gmail': 28, 'embarqmail.com': 29, 'earthlink.net': 30, 'cox.net': 31, 'comcast.net': 32, 'bellsouth.net': 33, 'att.net': 34, 'aol.com': 35, 'anonymous.com': 36, 'aim.com': 37}
#          isFraud       M1  percentage
# M1
# T              0        T   76.429539
# T              1        T   40.852130
# Unknown        0  Unknown   23.570461
# Unknown        1  Unknown   59.147870
# {'Unknown': 0, 'T': 1}
#          isFraud       M2  percentage
# M2
# F              0        F   10.144777
# F              1        F   10.025063
# T              0        T   66.284762
# T              1        T   30.827068
# Unknown        0  Unknown   23.570461
# Unknown        1  Unknown   59.147870
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud       M3  percentage
# M3
# F              0        F   17.654411
# F              1        F   14.786967
# T              0        T   58.775128
# T              1        T   26.065163
# Unknown        0  Unknown   23.570461
# Unknown        1  Unknown   59.147870
# {'Unknown': 0, 'T': 1, 'F': 2}
#     isFraud  M4  percentage
# M4
# M0        0  M0   83.251745
# M0        1  M0   62.155388
# M1        0  M1    9.936465
# M1        1  M1    7.268170
# M2        0  M2    6.811790
# M2        1  M2   30.576441
# {'M2': 0, 'M1': 1, 'M0': 2}
#          isFraud       M5  percentage
# M5
# F              0        F   23.705864
# F              1        F   20.802005
# T              0        T   20.831163
# T              1        T   18.045113
# Unknown        0  Unknown   55.462973
# Unknown        1  Unknown   61.152882
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud       M6  percentage
# M6
# F              0        F   42.110197
# F              1        F   25.062657
# T              0        T   37.943964
# T              1        T   18.045113
# Unknown        0  Unknown   19.945839
# Unknown        1  Unknown   56.892231
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud       M7  percentage
# M7
# F              0        F   58.337673
# F              1        F   30.827068
# T              0        T    8.686595
# T              1        T    5.513784
# Unknown        0  Unknown   32.975732
# Unknown        1  Unknown   63.659148
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud       M8  percentage
# M8
# F              0        F   43.776690
# F              1        F   26.065163
# T              0        T   23.247578
# T              1        T   10.275689
# Unknown        0  Unknown   32.975732
# Unknown        1  Unknown   63.659148
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud       M9  percentage
# M9
# F              0        F   12.050828
# F              1        F   11.278195
# T              0        T   54.973440
# T              1        T   25.062657
# Unknown        0  Unknown   32.975732
# Unknown        1  Unknown   63.659148
# {'Unknown': 0, 'T': 1, 'F': 2}
#           isFraud     id_12  percentage
# id_12
# Found           0     Found    3.635038
# Found           1     Found    9.523810
# NotFound        0  NotFound   12.707010
# NotFound        1  NotFound   45.614035
# Unknown         0   Unknown   83.657952
# Unknown         1   Unknown   44.862155
# {'Unknown': 0, 'NotFound': 1, 'Found': 2}
#          isFraud    id_15  percentage
# id_15
# Found          0    Found   92.125820
# Found          1    Found   83.959900
# New            0      New    6.499323
# New            1      New   10.526316
# Unknown        0  Unknown    1.374857
# Unknown        1  Unknown    5.513784
# {'Unknown': 0, 'New': 1, 'Found': 2}
#           isFraud     id_16  percentage
# id_16
# Found           0     Found    7.895011
# Found           1     Found   36.340852
# NotFound        0  NotFound    6.540985
# NotFound        1  NotFound   10.526316
# Unknown         0   Unknown   85.564004
# Unknown         1   Unknown   53.132832
# {'Unknown': 0, 'NotFound': 1, 'Found': 2}
#          isFraud    id_28  percentage
# id_28
# Found          0    Found    8.884491
# Found          1    Found   38.345865
# New            0      New    6.915946
# New            1      New   14.035088
# Unknown        0  Unknown   84.199563
# Unknown        1  Unknown   47.619048
# {'Unknown': 0, 'New': 1, 'Found': 2}
#           isFraud     id_29  percentage
# id_29
# Found           0     Found    8.842829
# Found           1     Found   38.345865
# NotFound        0  NotFound    6.957609
# NotFound        1  NotFound   14.035088
# Unknown         0   Unknown   84.199563
# Unknown         1   Unknown   47.619048
# {'Unknown': 0, 'NotFound': 1, 'Found': 2}
#                      isFraud                id_31  percentage
# id_31
# android browser 4.0        1  android browser 4.0    0.250627
# android webview 4.0        0  android webview 4.0    0.062493
# android webview 4.0        1  android webview 4.0    1.253133
# chrome                     1               chrome    0.501253
# chrome                     0               chrome    0.020831
# ...                      ...                  ...         ...
# samsung browser 4.0        0  samsung browser 4.0    0.020831
# samsung browser 4.2        0  samsung browser 4.2    0.010416
# samsung browser 6.4        0  samsung browser 6.4    0.072909
# samsung browser 6.4        1  samsung browser 6.4    1.253133
# samsung browser 7.0        0  samsung browser 7.0    0.052078
#
# [82 rows x 3 columns]
# {'samsung browser 7.0': 0, 'samsung browser 6.4': 1, 'samsung browser 4.2': 2, 'samsung browser 4.0': 3, 'samsung': 4, 'safari 9.0': 5, 'safari 11.0': 6, 'safari 10.0': 7, 'opera 53.0': 8, 'mobile safari 9.0': 9, 'mobile safari 11.0': 10, 'mobile safari 10.0': 11, 'ie 11.0 for tablet': 12, 'ie 11.0 for desktop': 13, 'ie': 14, 'google search application 49.0': 15, 'google': 16, 'firefox 60.0': 17, 'firefox 59.0': 18, 'firefox 57.0': 19, 'firefox 55.0': 20, 'firefox 52.0': 21, 'firefox 48.0': 22, 'firefox': 23, 'edge 17.0': 24, 'edge 16.0': 25, 'chrome 69.0': 26, 'chrome 67.0 for android': 27, 'chrome 67.0': 28, 'chrome 66.0 for ios': 29, 'chrome 66.0 for android': 30, 'chrome 66.0': 31, 'chrome 65.0 for ios': 32, 'chrome 65.0 for android': 33, 'chrome 65.0': 34, 'chrome 64.0 for android': 35, 'chrome 64.0': 36, 'chrome 63.0 for android': 37, 'chrome 63.0': 38, 'chrome 62.0': 39, 'chrome 61.0 for android': 40, 'chrome 60.0 for android': 41, 'chrome 59.0 for android': 42, 'chrome 59.0': 43, 'chrome 58.0 for android': 44, 'chrome 57.0 for android': 45, 'chrome 56.0 for android': 46, 'chrome 56.0': 47, 'chrome 55.0 for android': 48, 'chrome 55.0': 49, 'chrome 54.0 for android': 50, 'chrome 52.0 for android': 51, 'chrome 51.0': 52, 'chrome 50.0 for android': 53, 'chrome 49.0': 54, 'chrome': 55, 'android webview 4.0': 56, 'android browser 4.0': 57}
#          isFraud    id_35  percentage
# id_35
# F              0        F    7.082596
# F              1        F   34.335840
# T              0        T    8.728257
# T              1        T   18.045113
# Unknown        0  Unknown   84.189147
# Unknown        1  Unknown   47.619048
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud    id_36  percentage
# id_36
# F              0        F   14.977606
# F              1        F   49.874687
# T              0        T    0.833247
# T              1        T    2.506266
# Unknown        0  Unknown   84.189147
# Unknown        1  Unknown   47.619048
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud    id_37  percentage
# id_37
# F              0        F    3.582960
# F              1        F   10.275689
# T              0        T   12.227893
# T              1        T   42.105263
# Unknown        0  Unknown   84.189147
# Unknown        1  Unknown   47.619048
# {'Unknown': 0, 'T': 1, 'F': 2}
#          isFraud    id_38  percentage
# id_38
# F              0        F   10.373919
# F              1        F   40.601504
# T              0        T    5.436934
# T              1        T   11.779449
# Unknown        0  Unknown   84.189147
# Unknown        1  Unknown   47.619048
# {'Unknown': 0, 'T': 1, 'F': 2}
#             isFraud DeviceType  percentage
# DeviceType
# Unknown           0    Unknown   84.199563
# Unknown           1    Unknown   47.619048
# desktop           0    desktop    9.488595
# desktop           1    desktop   25.313283
# mobile            0     mobile    6.311843
# mobile            1     mobile   27.067669
# {'mobile': 0, 'desktop': 1, 'Unknown': 2}
#                      isFraud           DeviceInfo  percentage
# DeviceInfo
# 5010G Build/MRA58K         0   5010G Build/MRA58K    0.010416
# 5011A Build/NRD90M         0   5011A Build/NRD90M    0.010416
# 5012G Build/MRA58K         0   5012G Build/MRA58K    0.010416
# 5056A Build/MMB29M         0   5056A Build/MMB29M    0.020831
# A574BL Build/NMF26F        1  A574BL Build/NMF26F    0.250627
# ...                      ...                  ...         ...
# rv:55.0                    0              rv:55.0    0.020831
# rv:57.0                    0              rv:57.0    0.010416
# rv:59.0                    0              rv:59.0    0.031247
# rv:60.0                    0              rv:60.0    0.187480
# rv:60.0                    1              rv:60.0    0.501253
#
# [194 rows x 3 columns]
# {'rv:60.0': 0, 'rv:59.0': 1, 'rv:57.0': 2, 'rv:55.0': 3, 'rv:52.0': 4, 'rv:48.0': 5, 'rv:11.0': 6, 'moto': 7, 'iris50': 8, 'iris 820 Build/MRA58K': 9, 'iOS Device': 10, 'gxq6580_weg_l Build/LMY47I': 11, 'Z955A': 12, 'Z839': 13, 'Z835 Build/NMF26V': 14, 'XT1650 Build/NCLS26.118-23-13-6-5': 15, 'XT1635-02 Build/NPN26.118-22-2': 16, 'XT1058 Build/LPAS23.12-21.7-1': 17, 'Windows NT 6.1': 18, 'Windows': 19, 'WAS-LX3 Build/HUAWEIWAS-LX3': 20, 'WAS-LX1A Build/HUAWEIWAS-LX1A': 21, 'Trident/7.0': 22, 'TRT-L53 Build/HUAWEITRT-L53': 23, 'SM-T800 Build/MMB29K': 24, 'SM-T560 Build/KTU84P': 25, 'SM-T550 Build/NMF26X': 26, 'SM-T350 Build/NMF26X': 27, 'SM-T350 Build/MMB29M': 28, 'SM-T113NU Build/KTU84P': 29, 'SM-S902L': 30, 'SM-N950U Build/NMF26X': 31, 'SM-N910F Build/MMB29M': 32, 'SM-J730GM Build/NRD90M': 33, 'SM-J727T1 Build/NRD90M': 34, 'SM-J710MN Build/MMB29K': 35, 'SM-J701M Build/NRD90M': 36, 'SM-J700T Build/NMF26X': 37, 'SM-J700M Build/MMB29K': 38, 'SM-J700M Build/LMY48B': 39, 'SM-J530GM Build/NRD90M': 40, 'SM-J510MN Build/MMB29M': 41, 'SM-J500M Build/MMB29M': 42, 'SM-J110M Build/LMY48B': 43, 'SM-J105B Build/LMY47V': 44, 'SM-G965U Build/R16NW': 45, 'SM-G960U Build/R16NW': 46, 'SM-G9600 Build/R16NW': 47, 'SM-G955U1 Build/R16NW': 48, 'SM-G955U Build/R16NW': 49, 'SM-G955F Build/R16NW': 50, 'SM-G955F Build/NRD90M': 51, 'SM-G950U Build/R16NW': 52, 'SM-G950F Build/R16NW': 53, 'SM-G935V Build/NRD90M': 54, 'SM-G935P Build/NRD90M': 55, 'SM-G935F Build/NRD90M': 56, 'SM-G930T Build/NRD90M': 57, 'SM-G930P Build/NRD90M': 58, 'SM-G930F Build/NRD90M': 59, 'SM-G928G Build/NRD90M': 60, 'SM-G900T1': 61, 'SM-G900F Build/KOT49H': 62, 'SM-G800M Build/KOT49H': 63, 'SM-G610M Build/MMB29K': 64, 'SM-G610F Build/NRD90M': 65, 'SM-G570M Build/NRD90M': 66, 'SM-G570M Build/MMB29K': 67, 'SM-G550T1 Build/MMB29K': 68, 'SM-G532M Build/MMB29T': 69, 'SM-G531H Build/LMY48B': 70, 'SM-G355M Build/KOT49H': 71, 'SM-A720F Build/NRD90M': 72, 'SM-A710M Build/NRD90M': 73, 'SM-A520F Build/R16NW': 74, 'SM-A510M Build/NRD90M': 75, 'SM-A320Y Build/NRD90M': 76, 'SM-A310F Build/NRD90M': 77, 'SAMSUNG-SM-G928A Build/NRD90M': 78, 'SAMSUNG-SM-G900A Build/MMB29M': 79, 'SAMSUNG-SM-G900A Build/KOT49H': 80, 'SAMSUNG-SM-G890A Build/NRD90M': 81, 'SAMSUNG SM-T580 Build/NRD90M': 82, 'SAMSUNG SM-J700M Build/MMB29K': 83, 'SAMSUNG SM-G965U Build/R16NW': 84, 'SAMSUNG SM-G955U Build/R16NW': 85, 'SAMSUNG SM-G950U Build/R16NW': 86, 'SAMSUNG SM-G920I Build/NRD90M': 87, 'SAMSUNG SM-G920A Build/NRD90M': 88, 'SAMSUNG SM-G570M Build/NRD90M': 89, 'SAMSUNG SM-G570M Build/MMB29K': 90, 'SAMSUNG SM-G532M Build/MMB29T': 91, 'SAMSUNG SM-A310F Build/NRD90M': 92, 'SAMSUNG': 93, 'S.N.O.W.4': 94, 'Redmi Note 3 Build/MMB29M': 95, 'RNE-L03 Build/HUAWEIRNE-L03': 96, 'RCT6513W87 Build/MRA58K': 97, 'RCT6303W87M7 Build/MRA58K': 98, 'Pixel XL Build/OPM4.171019.016.B1': 99, 'Pixel Build/OPM4.171019.016.B1': 100, 'Pixel': 101, 'PRA-LX3 Build/HUAWEIPRA-LX3': 102, 'PRA-LX1 Build/HUAWEIPRA-LX1': 103, 'MotoG3 Build/MPIS24.65-33.1-2-16': 104, 'Moto Z2 Play Build/NPSS26.118-19-14': 105, 'Moto G Play Build/MPIS24.241-15.3-7': 106, 'Moto G (5) Plus Build/NPN25.137-92': 107, 'Moto G (5) Build/NPP25.137-93': 108, 'Moto G (5) Build/NPP25.137-82': 109, 'Moto G (4) Build/NPJS25.93-14-18': 110, 'Moto G (4) Build/NPJ25.93-14.7': 111, 'Moto E (4) Plus Build/NMA26.42-152': 112, 'Moto E (4) Build/NMA26.42-19': 113, 'Moto C Plus Build/NRD90M.05.034': 114, 'MacOS': 115, 'MYA-L13 Build/HUAWEIMYA-L13': 116, 'M4 SS4458 Build/MMB29M': 117, 'M4 SS4457 Build/MRA58K': 118, 'Linux x86_64': 119, 'Lenovo YT3-850M Build/MMB29M': 120, 'Lenovo YT3-850F Build/MMB29M': 121, 'Lenovo': 122, 'LG-X230 Build/MRA58K': 123, 'LG-X220 Build/LMY47I': 124, 'LG-X180g Build/LMY47I': 125, 'LG-SP320': 126, 'LG-M700 Build/NMF26X': 127, 'LG-M257': 128, 'LG-M150': 129, 'LG-LS777 Build/NRD90U': 130, 'LG-K580 Build/MRA58K': 131, 'LG-K530 Build/MMB29M': 132, 'LG-K500 Build/MMB29M': 133, 'LG-K212': 134, 'LG-H870 Build/NRD90U': 135, 'LG-H811 Build/MRA58K': 136, 'LG-H542 Build/MRA58K': 1 ...

# %%
test.head()
# Out:
#    TransactionID  TransactionDT  TransactionAmt  ProductCD  card1  card2  \
# 0        4160240       33940602           6.701          4  15885  545.0
# 1        4160241       33940623          32.277          4   5812  408.0
# 2        4160242       33940630         609.880          0   9537  583.0
# 3        4160243       33940634         100.000          3   6019  583.0
# 4        4160244       33940669           7.009          4   9633  130.0
#
#    card3  card4  card5  card6  ...      id-33           id-34    id-35  \
# 0  185.0      0  138.0      0  ...  1920x1080         Unknown        F
# 1  185.0      1  224.0      0  ...  1920x1080         Unknown        F
# 2  150.0      0  226.0      1  ...  1920x1080         Unknown  Unknown
# 3  150.0      0  226.0      1  ...  1920x1080  match_status:2        T
# 4  185.0      0  138.0      0  ...  1920x1080         Unknown        F
#
#      id-36    id-37    id-38  DeviceType  DeviceInfo  day  hour
# 0        F        T        F           1        19.0    6    19
# 1        F        T        F           0         NaN    6    19
# 2  Unknown  Unknown  Unknown           2        19.0    6    19
# 3        F        T        T           1       115.0    6    19
# 4        F        T        F           0         NaN    6    19
#
# [5 rows x 425 columns]

# %% [markdown]
# ## PCA

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(dataset.drop('isFraud', axis=1)) # We fit the data
# scaled_data_train = scaler.transform(dataset.drop('isFraud', axis=1))
# scaler.fit(test) # We fit the data
# scaled_data_test = scaler.transform(test)

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components=4)

# # Here we find ALL Principle Components using fit
# pca.fit(scaled_data_train)
# x_train_pca = pca.transform(scaled_data_train)

# pca.fit(scaled_data_test)
# x_test_pca = pca.transform(scaled_data_test)

# %%
# scaled_data_train.shape

# %%
# x_train_pca.shape

# %%
# x_train_pca = pd.DataFrame(x_train_pca)
# test_pca = pd.DataFrame(x_test_pca)

# %%
# dataset_pca = pd.concat([x_train_pca, dataset['isFraud']], axis=1)

# %% [markdown]
# ## Oversampling

# %%
from sklearn.utils import resample
not_fraud = dataset[dataset['isFraud'] == 0]
fraud = dataset[dataset['isFraud'] == 1]

# Replicate the samples from fraud
fraud_upsampled = resample(fraud,
                          replace=True, # sample with replacement
                          n_samples=len(not_fraud), # match number in majority class
                          random_state=27) # reproducible results
# combine majority and upsampled minority
upsampled_train = pd.concat([not_fraud, fraud_upsampled])

# check new class counts
print(upsampled_train.isFraud.value_counts())
# Out:
# 1    9601
# 0    9601
# Name: isFraud, dtype: int64

# %%
upsampled_train.to_csv('train_feateng', index=False)
test.to_csv('test_feateng', index=False)
